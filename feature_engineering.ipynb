# %%
import json
import time
from tqdm import trange, tqdm
import os
from typing import Dict, List, Tuple, Union

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
FILEPATH_CSV = "./csc108_fall2021.csv"

# %%
data = pd.read_csv(FILEPATH_CSV, index_col=0)
data.head()
data

# 2022-01-03T00:08:09Z   2022-01-03T00:51:25Z
# Out:
#                                                    question_title  \
# post_id
# kxxxcewo3k2kd                                      Summer Courses
# kxxrckc7d8827t                                  What should I do?
# kxxg3uqr8kc4ui  What is the yotube account that made pcrs videos?
# kxwl9h27m1h33z                             UTM Exam fail question
# kxves5858h42re                 In-person Learning For Winter Term
# ...                                                           ...
# kspl0arizjk45a  Spatial Skills: Pretest - Shapes difficult to ...
# kspgo42greo387           Question I make based on Week 1 material
# ksp2nuwazar3ao           Spatial skills: Orthographic Views 1, #3
# ksp12grb4ub7aj            I don't think I am in the right lecture
# ksovp64nskk4ui                    Ask Hints on Grading activities
#
#                                                          question  \
# post_id
# kxxxcewo3k2kd   Which of the computer science courses are goin...
# kxxrckc7d8827t  I failed csc108, so I'm going to re-take it. B...
# kxxg3uqr8kc4ui                                                NaN
# kxwl9h27m1h33z  Hi, I'm just confused about how the fail thing...
# kxves5858h42re  Hello, will all courses (such as CSC148H5 and ...
# ...                                                           ...
# kspl0arizjk45a  Hello,\n\n As I was doing the Spatial Skills P...
# kspgo42greo387  Hello:\nThere are question made by me to check...
# ksp2nuwazar3ao  Hello:\nAs I am doing the week 1 spatial Skill...
# ksp12grb4ub7aj  I am currently enrolled in CSC108H5 F LEC 9106...
# ksovp64nskk4ui  Hello:\nIf when we are stuck on some question ...
#
#                        folders student_poster_name  date_question_posted  \
# post_id
# kxxxcewo3k2kd   utm/life/other      ksoq5pmzwq514u  2022-01-03T00:08:09Z
# kxxrckc7d8827t         general      ksoq5tpdnh31kw  2022-01-02T21:20:18Z
# kxxg3uqr8kc4ui            pcrs      ks9l55ygvlm30f  2022-01-02T16:05:36Z
# kxwl9h27m1h33z  utm/life/other       ksoq5j54ygqp0  2022-01-02T01:42:10Z
# kxves5858h42re  utm/life/other      ksoq6sru6w34ak  2022-01-01T05:52:58Z
# ...                        ...                 ...                   ...
# kspl0arizjk45a         spatial      ksoq5p0f71h12q  2021-08-24T04:42:07Z
# kspgo42greo387         general      keivl0bhdc52f5  2021-08-24T02:40:40Z
# ksp2nuwazar3ao         spatial      keivl0bhdc52f5  2021-08-23T20:08:34Z
# ksp12grb4ub7aj         lecture      ksoq61vj96i2d4  2021-08-23T19:23:56Z
# ksovp64nskk4ui         general      keivl0bhdc52f5  2021-08-23T16:53:37Z
#
#                                                    student_answer  \
# post_id
# kxxxcewo3k2kd                                                 NaN
# kxxrckc7d8827t  There's a chance that csc148 can be taken in s...
# kxxg3uqr8kc4ui  https://youtube.com/channel/UCu8NnRGTGxHe96Le0...
# kxwl9h27m1h33z                                                NaN
# kxves5858h42re                                     I believe so.
# ...                                                           ...
# kspl0arizjk45a  Its the dark mode making the shapes look odd, ...
# kspgo42greo387  Q1) 8**6//4+6+6*8\n   = 262144//4+6+6*8\n   =6...
# ksp2nuwazar3ao  Just drop hints here: There will be some edges...
# ksp12grb4ub7aj                                                NaN
# ksovp64nskk4ui                                                NaN
#
#                student_answer_name date_student_answer_posted  \
# post_id
# kxxxcewo3k2kd                  NaN                        NaN
# kxxrckc7d8827t      ksoq6exja9d3b9       2022-01-02T21:26:51Z
# kxxg3uqr8kc4ui      kr2bzqy2dok7ou       2022-01-02T16:07:36Z
# kxwl9h27m1h33z                 NaN                        NaN
# kxves5858h42re      ksoq6sajaqn48y       2022-01-01T05:54:54Z
# ...                            ...                        ...
# kspl0arizjk45a      ksoq6px0rgz43d       2021-08-30T06:59:49Z
# kspgo42greo387       ksoq5rauj41c2       2021-08-25T06:55:53Z
# ksp2nuwazar3ao      keivl0bhdc52f5       2021-08-23T21:17:37Z
# ksp12grb4ub7aj                 NaN                        NaN
# ksovp64nskk4ui                 NaN                        NaN
#
#                 num_student_helpful  \
# post_id
# kxxxcewo3k2kd                   NaN
# kxxrckc7d8827t                  1.0
# kxxg3uqr8kc4ui                  0.0
# kxwl9h27m1h33z                  NaN
# kxves5858h42re                  0.0
# ...                             ...
# kspl0arizjk45a                  0.0
# kspgo42greo387                  0.0
# ksp2nuwazar3ao                  1.0
# ksp12grb4ub7aj                  NaN
# ksovp64nskk4ui                  NaN
#
#                                                 instructor_answer  \
# post_id
# kxxxcewo3k2kd   We will not know until March, when the summer ...
# kxxrckc7d8827t                                                NaN
# kxxg3uqr8kc4ui  There isn't a single account. Many of the vide...
# kxwl9h27m1h33z  The grade you've received on Acorn is Final. S...
# kxves5858h42re  > Does this mean I’ll be taking online courses...
# ...                                                           ...
# kspl0arizjk45a  Could you give us an example (screenshot) of o...
# kspgo42greo387                                                NaN
# ksp2nuwazar3ao  The key to this question is the dotted lines. ...
# ksp12grb4ub7aj  Hi Yaseen! Yes you are, all the lectures secti...
# ksovp64nskk4ui  General questions -- ones that you can ask wit...
#
#                instructor_answer_name date_instructor_answer_posted  \
# post_id
# kxxxcewo3k2kd             gzcyozk0MBl          2022-01-03T00:51:25Z
# kxxrckc7d8827t                    NaN                           NaN
# kxxg3uqr8kc4ui            gzcyozk0MBl          2022-01-02T16:08:36Z
# kxwl9h27m1h33z         jc6jo3gvkr8542          2022-01-02T01:43:55Z
# kxves5858h42re         jc6jo3gvkr8542          2022-01-01T06:13:30Z
# ...                               ...                           ...
# kspl0arizjk45a            gzcyozk0MBl          2021-08-24T04:45:41Z
# kspgo42greo387                    NaN                           NaN
# ksp2nuwazar3ao          k4ddfmb0gsb1h          2021-08-23T21:48:22Z
# ksp12grb4ub7aj          k4ddfmb0gsb1h          2021-08-24T00:56:12Z
# ksovp64nskk4ui            gzcyozk0MBl          2021-08-23T17:01:32Z
#
#                 num_instructor_helpful  is_followup
# post_id
# kxxxcewo3k2kd                      0.0        False
# kxxrckc7d8827t                     NaN        False
# kxxg3uqr8kc4ui                     0.0        False
# kxwl9h27m1h33z                     0.0         True
# kxves5858h42re                     0.0         True
# ...                                ...          ...
# kspl0arizjk45a                     0.0         True
# kspgo42greo387                     NaN         True
# ksp2nuwazar3ao                     1.0         True
# ksp12grb4ub7aj                     2.0        False
# ksovp64nskk4ui                     6.0         True
#
# [3117 rows x 14 columns]

# %%
import html
html.unescape('hello I&#39;m Bob')
# Out:
# "hello I'm Bob"

# %% [markdown]
# ## Textual and Non-Textual Features
#
# ### Textual - no NLP techniques
# - question/answer length
#   - code snippets start with "```" or "<pre> </pre>" tags
#   - omit q&a with images
#   - ignore images, hyperlinks and other html tags -> raw q/a length
# - level of answer detail
#   - links, imgs, code-snippets
#
# - duplicate post; rename to reference to other post
#   - check for annotation in response to determine if duplicate?
#
# #### Textual - NLP techniques
# - sentiment analysis **vs. politeness**
# - grammar/spelling
# - answer relevance to question
# - look at individual words and how they relate to is_helpful
#
# - discretize these features
#
#
# ### Non-Textual
# - *asker id*
# - response time (responder date) difference in time b/w question posted and response
# - *question creation date*
# - category/folder
#   - use general categories that are common across classes
#     - general/logistics/administrative/misc, lecture, assignment/lab/pcrs/spatial, test/exam,
#     - 0, 1, 2, 3, 4
# - is_followup
# - **reputation** rename to **authority**
# - public vs. private
#   - affects helpful bins since cannot be more than 1 helpful
# - **close to deadline?**
#   - need to manually augment data for this
#   - make continuous and add boundaries for use with decision tree
#
#
#
# * *italics* cannot be used for predicting future helpful answers since they are unique to question-answer pair

# %% [markdown]
# ## Mutual Information
#
# - idea that helpful = "positive feedback" instead of actually "helpful"
# - students click "helpful" as "positive feedback" instead of because answer is actually "helpful"
#
# ### Classification problem
# - binary classification.
#   - (question, answer)  -> helpful/not-helpful, very helpful, mildly helpful, unhelpful (break into 3 discrete categories)
#     - 0, 1, > 1
#     - most responses only get 0,1 or > 1 helpful
#
#
# (question, s_answer, i_answer)
# - split into 2?
#   - (question, s_answer, reputation)
#   - (question, i_answer, reputation)
#   - reputation = student|instructor|instr_endorsed_answerer
# - take helpful answer. If none, choose arbitrarily
#   - cannot use reputation as feature
#
#
#
# ## Feedback
#
# - ensure metrics are justified or come from literature
# - make a table of features with columns: whether feature exists in literature, if doesn't exist, brief justification, mutual information score, other scores
